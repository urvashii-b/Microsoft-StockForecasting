# %% [markdown]
# <a href="https://colab.research.google.com/github/urvashii-b/Microsoft-StockForecasting/blob/master/LSTM_MICROSOFT_STOCK_FORECASTING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # dataset @ https://finance.yahoo.com/quote/MSFT/history/

# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060274
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062427
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063503
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061889
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060812
# ...          ...         ...         ...         ...         ...         ...
# 9550  2024-02-05  409.899994  411.160004  403.989990  405.649994  405.649994
# 9551  2024-02-06  405.880005  407.970001  402.910004  405.489990  405.489990
# 9552  2024-02-07  407.440002  414.299988  407.399994  414.049988  414.049988
# 9553  2024-02-08  414.049988  415.559998  412.529999  414.109985  414.109985
# 9554  2024-02-09  415.250000  420.820007  415.089996  420.549988  420.549988
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9550    25352300
# 9551    18382600
# 9552    22340500
# 9553    21225300
# 9554    22012900
#
# [9555 rows x 7 columns]

# %%
df = df[['Date','Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9550  2024-02-05  405.649994
# 9551  2024-02-06  405.489990
# 9552  2024-02-07  414.049988
# 9553  2024-02-08  414.109985
# 9554  2024-02-09  420.549988
#
# [9555 rows x 2 columns]

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-7-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9550   2024-02-05
# 9551   2024-02-06
# 9552   2024-02-07
# 9553   2024-02-08
# 9554   2024-02-09
# Name: Date, Length: 9555, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2024-02-05  405.649994
# 2024-02-06  405.489990
# 2024-02-07  414.049988
# 2024-02-08  414.109985
# 2024-02-09  420.549988
#
# [9555 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 101ms/step - loss: 84746.6875 - mean_absolute_error: 289.3740 - val_loss: 92432.3438 - val_mean_absolute_error: 303.9398
# Epoch 2/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84505.6719 - mean_absolute_error: 288.9571 - val_loss: 92217.3906 - val_mean_absolute_error: 303.5859
# Epoch 3/100
# 7/7 [==============================] - 0s 9ms/step - loss: 84290.0234 - mean_absolute_error: 288.5806 - val_loss: 91917.3906 - val_mean_absolute_error: 303.0914
# Epoch 4/100
# 7/7 [==============================] - 0s 9ms/step - loss: 83930.6250 - mean_absolute_error: 287.9594 - val_loss: 91448.6484 - val_mean_absolute_error: 302.3172
# Epoch 5/100
# 7/7 [==============================] - 0s 9ms/step - loss: 83462.7109 - mean_absolute_error: 287.1442 - val_loss: 90882.8594 - val_mean_absolute_error: 301.3800
# Epoch 6/100
# 7/7 [==============================] - 0s 8ms/step - loss: 82840.0859 - mean_absolute_error: 286.0631 - val_loss: 90079.0312 - val_mean_absolute_error: 300.0434
# Epoch 7/100
# 7/7 [==============================] - 0s 10ms/step - loss: 81969.0156 - mean_absolute_error: 284.5284 - val_loss: 88934.0703 - val_mean_absolute_error: 298.1292
# Epoch 8/100
# 7/7 [==============================] - 0s 8ms/step - loss: 80673.5000 - mean_absolute_error: 282.2397 - val_loss: 87290.2031 - val_mean_absolute_error: 295.3593
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 78967.7500 - mean_absolute_error: 279.2044 - val_loss: 85117.7109 - val_mean_absolute_error: 291.6584
# Epoch 10/100
# 7/7 [==============================] - 0s 8ms/step - loss: 76581.1875 - mean_absolute_error: 274.8996 - val_loss: 82027.7734 - val_mean_absolute_error: 286.3123
# Epoch 11/100
# 7/7 [==============================] - 0s 9ms/step - loss: 73547.4844 - mean_absolute_error: 269.3051 - val_loss: 78826.5312 - val_mean_absolute_error: 280.6663
# Epoch 12/100
# 7/7 [==============================] - 0s 9ms/step - loss: 70448.3906 - mean_absolute_error: 263.4818 - val_loss: 75203.8750 - val_mean_absolute_error: 274.1365
# Epoch 13/100
# 7/7 [==============================] - 0s 9ms/step - loss: 66777.0078 - mean_absolute_error: 256.4298 - val_loss: 71086.0312 - val_mean_absolute_error: 266.5202
# Epoch 14/100
# 7/7 [==============================] - 0s 8ms/step - loss: 62796.0938 - mean_absolute_error: 248.5872 - val_loss: 66670.2266 - val_mean_absolute_error: 258.1030
# Epoch 15/100
# 7/7 [==============================] - 0s 9ms/step - loss: 58292.3594 - mean_absolute_error: 239.2896 - val_loss: 60968.4961 - val_mean_absolute_error: 246.8103
# Epoch 16/100
# 7/7 [==============================] - 0s 9ms/step - loss: 52558.6211 - mean_absolute_error: 226.9841 - val_loss: 54621.1211 - val_mean_absolute_error: 233.5976
# Epoch 17/100
# 7/7 [==============================] - 0s 8ms/step - loss: 46272.9141 - mean_absolute_error: 212.6616 - val_loss: 46990.0938 - val_mean_absolute_error: 216.6486
# Epoch 18/100
# 7/7 [==============================] - 0s 8ms/step - loss: 38881.3672 - mean_absolute_error: 194.4405 - val_loss: 39233.3281 - val_mean_absolute_error: 197.9398
# Epoch 19/100
# 7/7 [==============================] - 0s 9ms/step - loss: 31966.5293 - mean_absolute_error: 176.0239 - val_loss: 32142.9824 - val_mean_absolute_error: 179.1364
# Epoch 20/100
# 7/7 [==============================] - 0s 9ms/step - loss: 25562.9746 - mean_absolute_error: 156.6784 - val_loss: 25217.6484 - val_mean_absolute_error: 158.6335
# Epoch 21/100
# 7/7 [==============================] - 0s 9ms/step - loss: 19517.0020 - mean_absolute_error: 136.0834 - val_loss: 19190.1719 - val_mean_absolute_error: 138.3373
# Epoch 22/100
# 7/7 [==============================] - 0s 8ms/step - loss: 14416.8086 - mean_absolute_error: 115.6771 - val_loss: 13908.6514 - val_mean_absolute_error: 117.7097
# Epoch 23/100
# 7/7 [==============================] - 0s 10ms/step - loss: 10001.7129 - mean_absolute_error: 94.6994 - val_loss: 9344.7666 - val_mean_absolute_error: 96.3939
# Epoch 24/100
# 7/7 [==============================] - 0s 8ms/step - loss: 6536.2417 - mean_absolute_error: 74.0698 - val_loss: 5993.9355 - val_mean_absolute_error: 77.0777
# Epoch 25/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4119.9507 - mean_absolute_error: 55.4966 - val_loss: 3619.8184 - val_mean_absolute_error: 59.7231
# Epoch 26/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2545.5447 - mean_absolute_error: 40.7251 - val_loss: 2073.1436 - val_mean_absolute_error: 44.9464
# Epoch 27/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1660.4615 - mean_absolute_error: 33.3278 - val_loss: 1144.0526 - val_mean_absolute_error: 33.0316
# Epoch 28/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1219.0731 - mean_absolute_error: 29.3556 - val_loss: 644.3747 - val_mean_absolute_error: 24.3189
# Epoch 29/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1059.9087 - mean_absolute_error: 27.5613 - val_loss: 381.7312 - val_mean_absolute_error: 18.1319
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1015.2833 - mean_absolute_error: 26.9701 - val_loss: 253.3385 - val_mean_absolute_error: 14.2807
# Epoch 31/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1014.8132 - mean_absolute_error: 26.9455 - val_loss: 202.7177 - val_mean_absolute_error: 12.5162
# Epoch 32/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1016.8535 - mean_absolute_error: 26.9496 - val_loss: 203.0136 - val_mean_absolute_error: 12.5273
# Epoch 33/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1016.2387 - mean_absolute_error: 26.9512 - val_loss: 220.3397 - val_mean_absolute_error: 13.1602
# Epoch 34/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1013.1716 - mean_absolute_error: 26.9094 - val_loss: 237.5817 - val_mean_absolute_error: 13.7582
# Epoch 35/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1011.1673 - mean_absolute_error: 26.8877 - val_loss: 247.1373 - val_mean_absolute_error: 14.0776
# Epoch 36/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.9157 - mean_absolute_error: 26.8807 - val_loss: 250.8933 - val_mean_absolute_error: 14.2010
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1011.1124 - mean_absolute_error: 26.8774 - val_loss: 265.3194 - val_mean_absolute_error: 14.6644
# Epoch 38/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1009.9123 - mean_absolute_error: 26.8576 - val_loss: 267.7609 - val_mean_absolute_error: 14.7413
# Epoch 39/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1009.8799 - mean_absolute_error: 26.8597 - val_loss: 273.9100 - val_mean_absolute_error: 14.9329
# Epoch 40/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.2964 - mean_absolute_error: 26.8634 - val_loss: 285.4307 - val_mean_absolute_error: 15.2849
# Epoch 41/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1010.2726 - mean_absolute_error: 26.8613 - val_loss: 281.0165 - val_mean_absolute_error: 15.1511
# Epoch 42/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1010.3326 - mean_absolute_error: 26.8656 - val_loss: 284.3974 - val_mean_absolute_error: 15.2537
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1010.5884 - mean_absolute_error: 26.8699 - val_loss: 288.2770 - val_mean_absolute_error: 15.3705
# Epoch 44/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1010.0560 - mean_absolute_error: 26.8625 - val_loss: 288.6093 - val_mean_absolute_error: 15.3805
# Epoch 45/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1010.8188 - mean_absolute_error: 26.8744 - val_loss: 286.4826 - val_mean_absolute_error: 15.3168
# Epoch 46/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1008.3213 - mean_absolute_error: 26.8400 - val_loss: 294.2200 - val_mean_absolute_error: 15.5489
# Epoch 47/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1007.4040 - mean_absolute_error: 26.8266 - val_loss: 275.4590 - val_mean_absolute_error: 14.9916
# Epoch 48/100
# 7/7 [==============================] - 0s 12ms/step - loss: 941.9771 - mean_absolute_error: 26.1069 - val_loss: 262.9979 - val_mean_absolute_error: 14.6377
# Epoch 49/100
# 7/7 [==============================] - 0s 15ms/step - loss: 878.9815 - mean_absolute_error: 25.0679 - val_loss: 259.9090 - val_mean_absolute_error: 14.5599
# Epoch 50/100
# 7/7 [==============================] - 0s 19ms/step - loss: 868.2484 - mean_absolute_error: 24.9409 - val_loss: 220.0531 - val_mean_absolute_error: 13.2407
# Epoch 51/100
# 7/7 [==============================] - 0s 13ms/step - loss: 820.5452 - mean_absolute_error: 24.2139 - val_loss: 237.2709 - val_mean_absolute_error: 13.8662
# Epoch 52/100
# 7/7 [==============================] - 0s 15ms/step - loss: 781.7073 - mean_absolute_error: 23.5548 - val_loss: 211.1006 - val_mean_absolute_error: 12.9873
# Epoch 53/100
# 7/7 [==============================] - 0s 12ms/step - loss: 759.8492 - mean_absolute_error: 23.1031 - val_loss: 165.6450 - val_mean_absolute_error: 11.1967
# Epoch 54/100
# 7/7 [==============================] - 0s 12ms/step - loss: 765.9642 - mean_absolute_error: 23.3236 - val_loss: 386.7408 - val_mean_absolute_error: 18.4725
# Epoch 55/100
# 7/7 [==============================] - 0s 17ms/step - loss: 766.4230 - mean_absolute_error: 23.6010 - val_loss: 137.2190 - val_mean_absolute_error: 9.9152
# Epoch 56/100
# 7/7 [==============================] - 0s 13ms/step - loss: 721.8336 - mean_absolute_error: 22.6399 - val_loss: 322.8820 - val_mean_absolute_error: 16.7382
# Epoch 57/100
# 7/7 [==============================] - 0s 12ms/step - loss: 681.5708 - mean_absolute_error: 22.0159 - val_loss: 239.0436 - val_mean_absolute_error: 14.0231
# Epoch 58/100
# 7/7 [==============================] - 0s 16ms/step - loss: 633.1619 - mean_absolute_error: 21.1670 - val_loss: 96.2514 - val_mean_absolute_error: 8.0501
# Epoch 59/100
# 7/7 [==============================] - 0s 15ms/step - loss: 657.9091 - mean_absolute_error: 21.6068 - val_loss: 373.8552 - val_mean_absolute_error: 18.2804
# Epoch 60/100
# 7/7 [==============================] - 0s 15ms/step - loss: 586.3575 - mean_absolute_error: 20.3477 - val_loss: 121.3470 - val_mean_absolute_error: 9.3178
# Epoch 61/100
# 7/7 [==============================] - 0s 16ms/step - loss: 558.7457 - mean_absolute_error: 19.8985 - val_loss: 160.1771 - val_mean_absolute_error: 11.2244
# Epoch 62/100
# 7/7 [==============================] - 0s 14ms/step - loss: 502.4761 - mean_absolute_error: 18.7932 - val_loss: 266.9881 - val_mean_absolute_error: 15.2027
# Epoch 63/100
# 7/7 [==============================] - 0s 16ms/step - loss: 433.6179 - mean_absolute_error: 17.1028 - val_loss: 401.3271 - val_mean_absolute_error: 19.0990
# Epoch 64/100
# 7/7 [==============================] - 0s 12ms/step - loss: 430.0381 - mean_absolute_error: 16.8575 - val_loss: 204.8812 - val_mean_absolute_error: 13.0781
# Epoch 65/100
# 7/7 [==============================] - 0s 16ms/step - loss: 374.0045 - mean_absolute_error: 16.1089 - val_loss: 89.4112 - val_mean_absolute_error: 7.9132
# Epoch 66/100
# 7/7 [==============================] - 0s 16ms/step - loss: 315.9519 - mean_absolute_error: 14.2881 - val_loss: 102.9953 - val_mean_absolute_error: 8.6980
# Epoch 67/100
# 7/7 [==============================] - 0s 14ms/step - loss: 253.8885 - mean_absolute_error: 12.8882 - val_loss: 203.1733 - val_mean_absolute_error: 13.1297
# Epoch 68/100
# 7/7 [==============================] - 0s 10ms/step - loss: 229.7892 - mean_absolute_error: 12.2483 - val_loss: 188.8823 - val_mean_absolute_error: 12.5922
# Epoch 69/100
# 7/7 [==============================] - 0s 8ms/step - loss: 218.4577 - mean_absolute_error: 11.9021 - val_loss: 76.1536 - val_mean_absolute_error: 7.2604
# Epoch 70/100
# 7/7 [==============================] - 0s 8ms/step - loss: 142.1967 - mean_absolute_error: 9.0907 - val_loss: 31.6394 - val_mean_absolute_error: 4.9421
# Epoch 71/100
# 7/7 [==============================] - 0s 8ms/step - loss: 118.8213 - mean_absolute_error: 7.9415 - val_loss: 45.3794 - val_mean_absolute_error: 5.5712
# Epoch 72/100
# 7/7 [==============================] - 0s 10ms/step - loss: 102.5051 - mean_absolute_error: 7.4414 - val_loss: 31.6094 - val_mean_absolute_error: 4.8349
# Epoch 73/100
# 7/7 [==============================] - 0s 9ms/step - loss: 82.8862 - mean_absolute_error: 6.6829 - val_loss: 37.4075 - val_mean_absolute_error: 5.0127
# Epoch 74/100
# 7/7 [==============================] - 0s 9ms/step - loss: 69.7646 - mean_absolute_error: 6.1300 - val_loss: 44.2716 - val_mean_absolute_error: 5.2581
# Epoch 75/100
# 7/7 [==============================] - 0s 9ms/step - loss: 67.4920 - mean_absolute_error: 6.3760 - val_loss: 59.7710 - val_mean_absolute_error: 6.1330
# Epoch 76/100
# 7/7 [==============================] - 0s 11ms/step - loss: 56.9862 - mean_absolute_error: 5.7224 - val_loss: 52.6632 - val_mean_absolute_error: 5.6968
# Epoch 77/100
# 7/7 [==============================] - 0s 9ms/step - loss: 49.8421 - mean_absolute_error: 5.3924 - val_loss: 49.1896 - val_mean_absolute_error: 5.5013
# Epoch 78/100
# 7/7 [==============================] - 0s 9ms/step - loss: 41.9534 - mean_absolute_error: 4.8502 - val_loss: 37.0850 - val_mean_absolute_error: 4.9519
# Epoch 79/100
# 7/7 [==============================] - 0s 12ms/step - loss: 37.3733 - mean_absolute_error: 4.6723 - val_loss: 32.1050 - val_mean_absolute_error: 4.8233
# Epoch 80/100
# 7/7 [==============================] - 0s 9ms/step - loss: 35.9782 - mean_absolute_error: 4.6127 - val_loss: 38.6729 - val_mean_absolute_error: 4.9971
# Epoch 81/100
# 7/7 [==============================] - 0s 9ms/step - loss: 31.2669 - mean_absolute_error: 4.3875 - val_loss: 32.5922 - val_mean_absolute_error: 4.8206
# Epoch 82/100
# 7/7 [==============================] - 0s 9ms/step - loss: 31.3017 - mean_absolute_error: 4.3328 - val_loss: 35.3503 - val_mean_absolute_error: 4.8644
# Epoch 83/100
# 7/7 [==============================] - 0s 8ms/step - loss: 31.1225 - mean_absolute_error: 4.3257 - val_loss: 34.3740 - val_mean_absolute_error: 4.8424
# Epoch 84/100
# 7/7 [==============================] - 0s 8ms/step - loss: 34.8657 - mean_absolute_error: 4.7983 - val_loss: 32.2919 - val_mean_absolute_error: 4.7633
# Epoch 85/100
# 7/7 [==============================] - 0s 9ms/step - loss: 30.1547 - mean_absolute_error: 4.2471 - val_loss: 42.3786 - val_mean_absolute_error: 5.2345
# Epoch 86/100
# 7/7 [==============================] - 0s 8ms/step - loss: 29.8007 - mean_absolute_error: 4.4047 - val_loss: 99.7509 - val_mean_absolute_error: 8.3763
# Epoch 87/100
# 7/7 [==============================] - 0s 9ms/step - loss: 32.1726 - mean_absolute_error: 4.5868 - val_loss: 75.2878 - val_mean_absolute_error: 6.9829
# Epoch 88/100
# 7/7 [==============================] - 0s 10ms/step - loss: 26.7422 - mean_absolute_error: 4.0294 - val_loss: 62.7310 - val_mean_absolute_error: 6.2681
# Epoch 89/100
# 7/7 [==============================] - 0s 8ms/step - loss: 24.7304 - mean_absolute_error: 3.9151 - val_loss: 53.8545 - val_mean_absolute_error: 5.8815
# Epoch 90/100
# 7/7 [==============================] - 0s 8ms/step - loss: 22.6748 - mean_absolute_error: 3.8274 - val_loss: 56.7078 - val_mean_absolute_error: 6.0178
# Epoch 91/100
# 7/7 [==============================] - 0s 9ms/step - loss: 21.6580 - mean_absolute_error: 3.7088 - val_loss: 36.7471 - val_mean_absolute_error: 4.8744
# Epoch 92/100
# 7/7 [==============================] - 0s 8ms/step - loss: 27.3441 - mean_absolute_error: 4.2744 - val_loss: 33.2348 - val_mean_absolute_error: 4.7357
# Epoch 93/100
# 7/7 [==============================] - 0s 9ms/step - loss: 22.3305 - mean_absolute_error: 3.7498 - val_loss: 48.7082 - val_mean_absolute_error: 5.6233
# Epoch 94/100
# 7/7 [==============================] - 0s 9ms/step - loss: 20.1520 - mean_absolute_error: 3.5135 - val_loss: 72.7409 - val_mean_absolute_error: 6.8645
# Epoch 95/100
# 7/7 [==============================] - 0s 8ms/step - loss: 25.4386 - mean_absolute_error: 4.1252 - val_loss: 72.6946 - val_mean_absolute_error: 6.8793
# Epoch 96/100
# 7/7 [==============================] - 0s 9ms/step - loss: 21.2836 - mean_absolute_error: 3.6911 - val_loss: 45.5267 - val_mean_absolute_error: 5.4357
# Epoch 97/100
# 7/7 [==============================] - 0s 9ms/step - loss: 20.8239 - mean_absolute_error: 3.5549 - val_loss: 47.9162 - val_mean_absolute_error: 5.5850
# Epoch 98/100
# 7/7 [==============================] - 0s 9ms/step - loss: 20.5818 - mean_absolute_error: 3.6377 - val_loss: 36.2316 - val_mean_absolute_error: 4.8455
# Epoch 99/100
# 7/7 [==============================] - 0s 8ms/step - loss: 20.7950 - mean_absolute_error: 3.6183 - val_loss: 39.8854 - val_mean_absolute_error: 5.0548
# Epoch 100/100
# 7/7 [==============================] - 0s 8ms/step - loss: 18.2546 - mean_absolute_error: 3.4320 - val_loss: 34.3711 - val_mean_absolute_error: 4.7863

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 47ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
